# %%
# %run ./includes/configuration
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import json
movies = {"movie": []}
for i in range(8):
    with open(moviePipelinePath + f"movie_{i}.json") as f:
        data = json.load(f)
        movies["movie"].append(data["movie"])

dbutils.fs.put(rawPath, json.dumps(movies, indent=2), True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 12795544 bytes.
# Out[3]: True</div>

# %%
display(dbutils.fs.ls(rawPath))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>raw</td><td>12795544</td><td>1661275260000</td></tr></tbody></table></div>

# %%
dbutils.fs.rm(bronzePath, recurse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: False</div>

# %%
kafka_schema = "value STRING"

movie_data_df = (
  spark.read.format("text").schema(kafka_schema).load(rawPath)
  
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(movie_data_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>{</td></tr><tr><td>  "movie": [</td></tr><tr><td>    [</td></tr><tr><td>      {</td></tr><tr><td>        "Id": 1,</td></tr><tr><td>        "Title": "Inception",</td></tr><tr><td>        "Overview": "Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: \"inception\", the implantation of another person's idea into a target's subconscious.",</td></tr><tr><td>        "Tagline": "Your mind is the scene of the crime.",</td></tr><tr><td>        "Budget": 160000000.0,</td></tr><tr><td>        "Revenue": 825532764.0,</td></tr><tr><td>        "ImdbUrl": "https://www.imdb.com/title/tt1375666",</td></tr><tr><td>        "TmdbUrl": "https://www.themoviedb.org/movie/27205",</td></tr><tr><td>        "PosterUrl": "https://image.tmdb.org/t/p/w342//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg",</td></tr><tr><td>        "BackdropUrl": "https://image.tmdb.org/t/p/original//s3TBrRGB1iav7gFOCNx3H31MoES.jpg",</td></tr><tr><td>        "OriginalLanguage": "en",</td></tr><tr><td>        "ReleaseDate": "2010-07-15T00:00:00",</td></tr><tr><td>        "RunTime": 148,</td></tr><tr><td>        "Price": 9.9,</td></tr><tr><td>        "CreatedDate": "2021-04-03T16:51:30.1633333",</td></tr><tr><td>        "UpdatedDate": null,</td></tr><tr><td>        "UpdatedBy": null,</td></tr><tr><td>        "CreatedBy": null,</td></tr><tr><td>        "genres": [</td></tr><tr><td>          {</td></tr><tr><td>            "id": 1,</td></tr><tr><td>            "name": "Adventure"</td></tr><tr><td>          },</td></tr><tr><td>          {</td></tr><tr><td>            "id": 6,</td></tr><tr><td>            "name": "Action"</td></tr><tr><td>          },</td></tr><tr><td>          {</td></tr><tr><td>            "id": 13,</td></tr><tr><td>            "name": "Science Fiction"</td></tr><tr><td>          }</td></tr><tr><td>        ]</td></tr><tr><td>      },</td></tr><tr><td>      {</td></tr><tr><td>        "Id": 2,</td></tr><tr><td>        "Title": "Interstellar",</td></tr><tr><td>        "Overview": "The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.",</td></tr><tr><td>        "Tagline": "Mankind was born on Earth. It was never meant to die here.",</td></tr><tr><td>        "Budget": 165000000.0,</td></tr><tr><td>        "Revenue": 675120017.0,</td></tr><tr><td>        "ImdbUrl": "https://www.imdb.com/title/tt0816692",</td></tr><tr><td>        "TmdbUrl": "https://www.themoviedb.org/movie/157336",</td></tr><tr><td>        "PosterUrl": "https://image.tmdb.org/t/p/w342//gEU2QniE6E77NI6lCU6MxlNBvIx.jpg",</td></tr><tr><td>        "BackdropUrl": "https://image.tmdb.org/t/p/original//xJHokMbljvjADYdit5fK5VQsXEG.jpg",</td></tr><tr><td>        "OriginalLanguage": "en",</td></tr><tr><td>        "ReleaseDate": "2014-11-05T00:00:00",</td></tr><tr><td>        "RunTime": 169,</td></tr><tr><td>        "Price": 9.9,</td></tr><tr><td>        "CreatedDate": "2021-04-03T16:51:30.1633333",</td></tr><tr><td>        "UpdatedDate": null,</td></tr><tr><td>        "UpdatedBy": null,</td></tr><tr><td>        "CreatedBy": null,</td></tr><tr><td>        "genres": [</td></tr><tr><td>          {</td></tr><tr><td>            "id": 1,</td></tr><tr><td>            "name": "Adventure"</td></tr><tr><td>          },</td></tr><tr><td>          {</td></tr><tr><td>            "id": 4,</td></tr><tr><td>            "name": "Drama"</td></tr><tr><td>          },</td></tr><tr><td>          {</td></tr><tr><td>            "id": 13,</td></tr><tr><td>            "name": "Science Fiction"</td></tr><tr><td>          }</td></tr><tr><td>        ]</td></tr><tr><td>      },</td></tr><tr><td>      {</td></tr><tr>< ...

# %%
from pyspark.sql.functions import current_timestamp, lit

movie_data_df = (
  movie_data_df.select(
   "value",
lit(f"dbfs:/dbfs/FileStore/movie/raw").alias("datasource"),
    current_timestamp().alias ("ingesttime"),
    lit("new").alias("status"),
    current_timestamp().cast("date").alias("ingestdate")
  )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import col

(
  movie_data_df.select(
  "datasource",
  "ingesttime",
  "value",
  "status",
  col("ingestdate").alias("p_ingestdate"),
  )
  .write.format("delta")
  .mode("append")
  .partitionBy("p_ingestdate")
  .save(bronzePath)
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls(bronzePath))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/dbfs/FileStore/movie/bronze/_delta_log/</td><td>_delta_log/</td><td>0</td><td>1661276013000</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/bronze/p_ingestdate=2022-08-23/</td><td>p_ingestdate=2022-08-23/</td><td>0</td><td>1661276002000</td></tr></tbody></table></div>

# %%
spark.sql("""
DROP TABLE IF EXISTS movie_bronze;
""")

spark.sql(f"""
CREATE TABLE movie_bronze
USING DELTA
LOCATION "{bronzePath}"
""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: DataFrame[]</div>

# %%
# %sql

SELECT * FROM movie_bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datasource</th><th>ingesttime</th><th>value</th><th>status</th><th>p_ingestdate</th></tr></thead><tbody><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>{</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>  "movie": [</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>    [</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>      {</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Id": 1,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Title": "Inception",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Overview": "Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: \"inception\", the implantation of another person's idea into a target's subconscious.",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Tagline": "Your mind is the scene of the crime.",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Budget": 160000000.0,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Revenue": 825532764.0,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "ImdbUrl": "https://www.imdb.com/title/tt1375666",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "TmdbUrl": "https://www.themoviedb.org/movie/27205",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "PosterUrl": "https://image.tmdb.org/t/p/w342//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "BackdropUrl": "https://image.tmdb.org/t/p/original//s3TBrRGB1iav7gFOCNx3H31MoES.jpg",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "OriginalLanguage": "en",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "ReleaseDate": "2010-07-15T00:00:00",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "RunTime": 148,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Price": 9.9,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "CreatedDate": "2021-04-03T16:51:30.1633333",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "UpdatedDate": null,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "UpdatedBy": null,</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "CreatedBy": null,</td><td>new</td><t ...

# %%
# %sql

SELECT * FROM movie_bronze WHERE value RLIKE 'Inception'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>datasource</th><th>ingesttime</th><th>value</th><th>status</th><th>p_ingestdate</th></tr></thead><tbody><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Title": "Inception: The Cobol Job",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Overview": "The Cobol Job is a fourteen-minute animated prequel to Christopher Nolan\u2019s award-winning movie: Inception, detailing the heist on Mr. Kaneda's mind by Nash, Cobb, Arthur, and several Cobol Engineering thugs.",</td><td>new</td><td>2022-08-23</td></tr><tr><td>dbfs:/dbfs/FileStore/movie/raw</td><td>2022-08-23T17:33:19.501+0000</td><td>        "Title": "Inception",</td><td>new</td><td>2022-08-23</td></tr></tbody></table></div>
